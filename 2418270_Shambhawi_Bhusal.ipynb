# %% [markdown]
# 3.1 Problem - 1: Getting Started with Data Exploration - Some Warm up
# Exercises:

# %%
# Import pandas
import pandas as pd

# %%
# path of the dataset
dataset = pd.read_csv('/content/drive/MyDrive/Concepts of technologies and AI/World Happiness Report.csv')
dataset
# Out:
#          Country name  score  Log GDP per capita  Social support  \
# 0             Finland  7.741               1.844           1.572
# 1             Denmark  7.583               1.908           1.520
# 2             Iceland  7.525               1.881           1.617
# 3              Sweden  7.344               1.878           1.501
# 4              Israel  7.341               1.803           1.513
# ..                ...    ...                 ...             ...
# 138  Congo (Kinshasa)  3.295               0.534           0.665
# 139      Sierra Leone  3.245               0.654           0.566
# 140           Lesotho  3.186               0.771           0.851
# 141           Lebanon  2.707               1.377           0.577
# 142       Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.695                         0.859       0.142
# ...

# %% [markdown]
# 1. Data Exploration and Understanding:
#
#   • Dataset Overview:
#     1. Load the dataset and display the first 10 rows.
#     2. Identify the number of rows and columns in the dataset.
#     3. List all the columns and their data types.

# %%
# 1.
# displaying the first 10 rows
dataset.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
# 2.
# identifying shape of dataset
num_rows, num_columns = dataset.shape
print(f"Rows in dataset: {num_rows}")
print(f"Columns in dataset: {num_columns}")
# Out:
# Rows in dataset: 143
# Columns in dataset: 9

# %%
# 3.
# listing all the columns andtheir datatypes
print(dataset.dtypes)
# Out:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# • Basic Statistics:
#    1. Calculate the mean, median, and
#       standard deviation for the Score column.
#    2. Identify the country with the
#       highest and lowest happiness scores.

# %%
# 1.
# calculating mean for Score column
score_mean = dataset['score'].mean()

# calculating median for Score column
score_median = dataset['score'].median()

# calculating standard deviation for Score column
score_standard_deviation = dataset['score'].std()

# printing outputs
print(f"The Mean for Score column is: {score_mean}")
print(f"The Median for Score column is: {score_median}")
print(f"The Standard Deviation for Score column is: {score_standard_deviation}")
# Out:
# The Mean for Score column is: 5.52758041958042
# The Median for Score column is: 5.785
# The Standard Deviation for Score column is: 1.1707165099442995

# %%
# 2.
# identyfying the country with highest happiness score
highest_score_row = dataset.loc[dataset['score'].idxmax()]
highest_score_country = highest_score_row['Country name']
highest_score = highest_score_row['score']

# identifying the country with lowest happiness score
lowest_score_row = dataset.loc[dataset['score'].idxmin()]
lowest_score_country = lowest_score_row['Country name']
lowest_score = lowest_score_row['score']

# printing outputs
print(f"Country with highest happiness score is: {highest_score_country}")
print(f"Country with lowest happiness score is: {lowest_score_country}")
# Out:
# Country with highest happiness score is: Finland
# Country with lowest happiness score is: Afghanistan

# %% [markdown]
# • Missing Values:
#    1. Check if there are any missing values in the dataset. If so, display the
#       total count for each column.

# %%
# 1.
# checking missing values and displaying the total count for each column
missing_values = dataset.isnull().sum()

# printing output
missing_values
# Out:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# • Filtering and Sorting:
#    1. Filter the dataset to show only the countries with a Score greater than 7.5.
#    2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the top 10 rows

# %%
# 1.
# filtering dataset and showing the countries with a score greater than 7.5
filtered_dataset = dataset[dataset['score']  > 7.5]

# printing output
filtered_dataset
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %%
# 2.
# sorting dataset by GDP per capita in desending order
sorted_dataset = filtered_dataset.sort_values(by = 'Log GDP per capita', ascending = False)

# displaying top 10 rows
top_10_rows = sorted_dataset.head(10)

# printing output
top_10_rows
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %% [markdown]
# • Adding New Columns:
#    1. Create a new column called Happiness Category that categorizes countries
#       into three categories based on their Score:
#           Low − (Score < 4)
#           Medium − (4 ≤ Score ≤ 6)
#           High − (Score > 6)

# %%
# 1.
# categorizing countries scores by defining a function
def categorize_countries_score(score):
    if(score < 4):
      return 'Low'
    elif(4 <= score <= 6):
      return 'Medium'
    else:
      return 'High'

# creating a new column by applying the function
dataset['Happiness Category'] = dataset['score'].apply(categorize_countries_score)

# displaying dataset
dataset
# Out:
#          Country name  score  Log GDP per capita  Social support  \
# 0             Finland  7.741               1.844           1.572
# 1             Denmark  7.583               1.908           1.520
# 2             Iceland  7.525               1.881           1.617
# 3              Sweden  7.344               1.878           1.501
# 4              Israel  7.341               1.803           1.513
# ..                ...    ...                 ...             ...
# 138  Congo (Kinshasa)  3.295               0.534           0.665
# 139      Sierra Leone  3.245               0.654           0.566
# 140           Lesotho  3.186               0.771           0.851
# 141           Lebanon  2.707               1.377           0.577
# 142       Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.695                         0.859       0.142
# ...

# %% [markdown]
# 2. Data Visualizations:
#
#    • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.
#
#    • Line Plot: Plot the top 10 unhappiest countries by Score using a Line
#      chart.
#
#    • Plot a histogram for the Score column to show its distribution and also
#      interpret.
#
#    • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to
#      visualize their relationship.

# %%
import matplotlib.pyplot as plt
# Bar Plot:

# selecting top 10 happiest countries
top_10_happiest = dataset.sort_values(by = 'score', ascending = False).head(10)

# creating a bar plot
plt.figure(figsize = (10, 6))
plt.bar(top_10_happiest['Country name'], top_10_happiest['score'], color = 'pink')
plt.xlabel('Country name')
plt.ylabel('score')
plt.title('Top 10 Happiest Countries by Score')
plt.xticks(rotation = 45)

# displaying plot
plt.show()

# %%
# Line Plot:

# selecting top 10 unhappiest countries
top_10_unhappiest = dataset.sort_values(by = 'score').head(10)

# creating a Line plot
plt.figure(figsize = (10, 6))
plt.plot(top_10_unhappiest['Country name'], top_10_unhappiest['score'], marker = 'o', linestyle = '-', color = 'green')
plt.xlabel('Country name')
plt.ylabel('score')
plt.title('Top 10 Unhappiest Countries by score')
plt.xticks(rotation = 45)

# displaying plot
plt.show()

# %%
# Histogram Plot:

# creating a histogram plot for the Score column to show its distribution
plt.figure(figsize = (10, 6))
plt.hist(dataset['score'], bins = 20, color = 'green', edgecolor = 'black')
plt.xlabel('score')
plt.ylabel('Frequency')
plt.title('Distribution of Scores')

# displaying plot
plt.show()

# %%
# Scatter Plot:

# creating a Scatter plot for visualizing relationship between GDP per Capita and Score
plt.figure(figsize = (10, 6))
plt.scatter(dataset['Log GDP per capita'], dataset['score'], color = 'blue')
plt.xlabel('GDP per Capita')
plt.ylabel('score')
plt.title('Scatter plot between GDP per Capita and Score')

# displaying plot
plt.show()

# %% [markdown]
# 3.2 Problem - 2 - Some Advance Data Exploration Task:

# %% [markdown]
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:
#
# Steps:
#
#     1. Define the countries in South Asia with a list for example: south asian
#        countries = ["Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
#     2. Use the list from step - 1 to filtered the dataset {i.e. filtered out
#        matching dataset from list.}
#
#     3. Save the filtered dataframe as separate CSV files for future use

# %%
# 1.
# defining countries in South Asia with a list
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

# %%
# 2.
# filtering dataframe
south_asia_dataset = dataset[dataset['Country name'].isin(south_asian_countries)]
# displaying filtered dataset
south_asia_dataset
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %%
# 3.
# saving the filtered dataframe as separate CSV file
south_asia_dataset.to_csv('/content/drive/MyDrive/Concepts of technologies and AI/south_asia_dataframe.csv', index = False)

# %% [markdown]
# Task - 2 - Composite Score Ranking:
#
# Tasks:
#
#    1. Using the SouthAsia DataFrame, create a new column called Composite Score
#       that combines the following metrics:
#         Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support + 0.30 × Healthy Life Expectancy
#
#    2. Rank the South Asian countries based on the Composite Score in     descending  order.
#    3. Visualize the top 5 countries using a horizontal bar chart showing the
#        Composite Score.
#    4. Discuss whether the rankings based on the Composite Score align with the original Score - support your discussion with some visualization plot.

# %%
# 1.
# creating new column composite score
south_asia_dataset['Composite Score'] = (0.40 * south_asia_dataset['Log GDP per capita'] + 0.30 * south_asia_dataset['Social support'] + 0.30 * south_asia_dataset['Healthy life expectancy'])
# displaying updated dataset
south_asia_dataset
# Out:
# <ipython-input-64-277be87d0678>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asia_dataset['Composite Score'] = (0.40 * south_asia_dataset['Log GDP per capita'] + 0.30 * south_asia_dataset['Social support'] + 0.30 * south_asia_dataset['Healthy life expectancy'])
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
# ...

# %%
# 2.
# ranking the South Asian countries based on the Composite Score in descending order
ranked_dataset = south_asia_dataset.sort_values(by = 'Composite Score', ascending = False)
# displaying the ranked data set
ranked_dataset
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 127    Sri Lanka  3.898               1.361           1.179
# 92         Nepal  5.158               0.965           0.990
# 125        India  4.054               1.166           0.653
# 107     Pakistan  4.657               1.069           0.600
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 127                    0.586                         0.583       0.144
# 92                     0.443                         0.653       0.209
# 125                    0.417                         0.767       0.174
# 107                    0.321                         0.542       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %%
# 3.

# selecting top 5 countries for visualization
top_5_countries = ranked_dataset.head(5)

# creating a horizontal bar chart
plt.figure(figsize = (10, 6))
plt.barh(top_5_countries['Country name'], top_5_countries['Composite Score'], color = 'yellow')
plt.xlabel('Composite Score')
plt.ylabel('Country name')
plt.title('Composite Score of top 5 countries')
plt.gca().invert_yaxis()  # for having highest score at the top
# displaying the horizontal bar chart
plt.show()

# %% [markdown]
# # 4.
# In this below scatter plot of relationship between Composite Score and score. The points represents each country, X-axis represents Composite Score and Y-axis represents Score. The points are more scattered so, Composite score and the original Score doesnot correspond perfectly.

# %%
# 4.
# creating scatter plot to visualize whether the rankings based on the Composite Score align with the original Score
plt.figure(figsize = (10, 6))
plt.scatter(south_asia_dataset['Composite Score'], south_asia_dataset['score'], color = 'purple')
plt.xlabel('Composite Score')
plt.ylabel('score')
plt.title('Relationship between Composite Score and score')
# displaying scatter plot
plt.show()

# %% [markdown]
# Task - 3 - Outlier Detection:
#
# Tasks:
#
#   1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
#
#   2. Define outliers using the 1.5 × IQR rule.
#
#   3. Create a scatter plot with GDP per Capita on the x-axis and Score on the   y-axis, highlighting outliers in a different color.
#   4. Discuss the characteristics of these outliers and their potential impact on regional averages

# %%
# 2.
# defining outliers using the 1.5 * IQR rule
# calculating IQR for score
Q1_score = south_asia_dataset['score'].quantile(0.25)
Q3_score = south_asia_dataset['score'].quantile(0.75)
IQR_score = Q3_score - Q1_score

# calculating IQR for score
Q1_gdp = south_asia_dataset['Log GDP per capita'].quantile(0.25)
Q3_gdp =south_asia_dataset['Log GDP per capita'].quantile(0.75)
IQR_gdp = Q3_gdp - Q1_gdp

# calculating upper bound and lower bound for outliers for gdp
lower_bound_gdp = Q1_gdp - 1.5 * IQR_gdp
upper_bound_gdp = Q3_gdp + 1.5 * IQR_gdp

# calculating upper bound and lower bound for outliers for score
lower_bound_score = Q1_score - 1.5 * IQR_score
upper_bound_score = Q3_score + 1.5 * IQR_score

# %%
# 1.
# identifying outliers
outliers = south_asia_dataset[(south_asia_dataset['score'] < lower_bound_score) | (south_asia_dataset['score'] > upper_bound_score) | (south_asia_dataset['Log GDP per capita'] < lower_bound_gdp) | (south_asia_dataset['Log GDP per capita'] > upper_bound_gdp)]
# displaying outliers
outliers
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 142  Afghanistan  1.721               0.628             0.0
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 142                    0.242                           0.0       0.091
#
#      Perceptions of corruption  Dystopia + residual Happiness Category  \
# 142                      0.088                0.672                Low
#
#      Composite Score
# 142           0.3238

# %%
# 3.
# creating scatter plot with GDP per Capita on the x-axis and Score on the y-axis
plt.figure(figsize = (10, 6))
plt.scatter(south_asia_dataset['Log GDP per capita'], south_asia_dataset['score'], color = 'skyblue', label = 'Normal')
plt.scatter(outliers['Log GDP per capita'], outliers['score'], color ='green', label = 'outliers')
plt.xlabel('Log GDP per capita')
plt.ylabel('score')
plt.title('Relation between Log GDP per capita and score(highlighting outliers)')
plt.legend()

# displaying scatter plot
plt.show()

# %% [markdown]
# 4.
# Outliers are the data points which are significantly different from other observations.
#
# Characterstics of Outliers in South asia are:-
# 1. High GDP per capita but low score.
# 2. Low GDP per capita but high score.
#
# Their potential impact on regional averages are:-
# 1. Skewing Averages
# 2. Misleading Insights
# 3. Highlighting Unique cases

# %% [markdown]
# Task - 4 - Exploring Trends Across Metrics:
#
# Tasks:
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation {pearson correlation} with the Score for South Asian countries.
# 2. Create scatter plots with trendlines for these metrics against the Score.
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for South Asian countries

# %%
# 1.
# calculating correlation using pearson correlation
correlation_freedom = south_asia_dataset['Freedom to make life choices'].corr(south_asia_dataset['score'])
correlation_generosity = south_asia_dataset['Generosity'].corr(south_asia_dataset['score'])

# printing output
print(f"Pearson correlation between Freedom to Make Life Choices and Score: {correlation_freedom}")
print(f"Pearson correlation between Generosity and Score: {correlation_generosity}")
# Out:
# Pearson correlation between Freedom to Make Life Choices and Score: 0.8005185224163315
# Pearson correlation between Generosity and Score: 0.874512371253192

# %%
import seaborn as sns
# 2.
# creating scatter plot with trendlines for freedom to make life choices against score
plt.figure(figsize = (10, 6))
sns.regplot(x = 'Freedom to make life choices', y = 'score', data = south_asia_dataset, color = 'purple')
plt.xlabel('Freedom to make life choices')
plt.ylabel('score')
plt.title('Freedom to Make Life Choices against Score')
plt.show()

# creating scatter plot with trendlines for Generosity against Score
plt.figure(figsize= (10, 6))
sns.regplot(x = 'Generosity', y = 'score', data = south_asia_dataset, color = 'green')
plt.xlabel('Generosity')
plt.ylabel('score')
plt.title('Generosity against Score')
plt.show()

# %% [markdown]
# 3.
# The strongest relationship between these metrics and the Score for South Asian countries are:-
#
# The metric with the highest absolute value of the Pearson correlation coefficient indicates the strongest relationship with the score.
# Pearson correlation between Generosity and Score: 0.874512371253192 is the strongest one.
#
#
# The weakest relationship between these metrics and the Score for South Asian countries are:-
# The metric with the lowest absolute value of the Pearson correlation coefficient indicates the strongest relationship with the score.
# Pearson correlation between Freedom to Make Life Choices and Score: 0.8005185224163315 is the weakest one.

# %% [markdown]
# Task - 5 - Gap Analysis:
#
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score for each South Asian country.
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
# 1.
# adding new colomn, GDP-Score Gap
south_asia_dataset['GDP Score Gap'] = south_asia_dataset['Log GDP per capita'] - south_asia_dataset['score']

# displaying the updated dataset
south_asia_dataset
# Out:
# <ipython-input-73-364410513fa1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asia_dataset['GDP Score Gap'] = south_asia_dataset['Log GDP per capita'] - south_asia_dataset['score']
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %%
# 2.
# ranking south asia countries by GDP Score gap in ascending order
ranked_ascending = south_asia_dataset.sort_values(by = 'GDP Score Gap')

# printing output
print(f"Ranked in ascending order: ")
ranked_ascending
# Out:
# Ranked in ascending order:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 128   Bangladesh  3.886               1.122           0.249
# 127    Sri Lanka  3.898               1.361           1.179
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 128                    0.513                         0.775       0.140
# 127                    0.586                         0.583       0.144
# 142                    0.242                         0.000       0.091
#
# ...

# %%
# ranking south asia countries by GDP Score gap in descending order
ranked_descending = south_asia_dataset.sort_values(by = 'GDP Score Gap', ascending = False)

# printing output
print("Ranked in Descending Order: ")
ranked_descending
# Out:
# Ranked in Descending Order:
#     Country name  score  Log GDP per capita  Social support  \
# 142  Afghanistan  1.721               0.628           0.000
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 125        India  4.054               1.166           0.653
# 107     Pakistan  4.657               1.069           0.600
# 92         Nepal  5.158               0.965           0.990
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 142                    0.242                         0.000       0.091
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 125                    0.417                         0.767       0.174
# 107                    0.321                         0.542       0.144
# 92                     0.443                         0.653       0.209
#
# ...

# %%
# 3.
# selecting top 3 countries with the largest positive gaps
top_3_positive_gaps = ranked_descending.head(3)

# selecting top 3 countries with largest negative gaps
top_3_negative_gaps = ranked_ascending.head(3)

# creating bar chart for larges positive gaps
plt.figure(figsize = (10, 6))
plt.bar(top_3_positive_gaps['Country name'], top_3_positive_gaps['GDP Score Gap'], color = 'blue')
plt.xlabel('Country name')
plt.ylabel('GDP Score Gap')
plt.title('Top 3 countries with largest positive GDP Score gaps')
plt.gca().invert_yaxis()
plt.show()

# creating bar chart for larges negative gaps
plt.figure(figsize=(10, 6))
plt.bar(top_3_negative_gaps['Country name'], top_3_negative_gaps['GDP Score Gap'], color='green')
plt.xlabel('Country name')
plt.ylabel('GDP Score Gap')
plt.title('Top 3 Countries with Largest Negative GDP Score Gaps')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# 4.
# The reasons behind these gaps and their implications for South Asian countries are:-
# 1. Positive Gaps:- Countries with large  positive gaps may have high GDP per capita but lower scores.
# 2. Negative GAps:- Countries with large negative gaps may have lower GDP per capita but higher scores.

# %% [markdown]
# 3.3 Problem - 3 - Comparative Analysis:
#
# Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:
#
# Tasks:
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
#
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
# "United Arab Emirates", "Yemen"]

# %%
# 1.
# defining middle east countries
middle_east_countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]

# filtering dataset to only include only the countries in Middle east countries
middle_east_dataset = dataset[dataset['Country name'].isin(middle_east_countries)]

# saving filtered dataset
middle_east_dataset.to_csv('/content/drive/MyDrive/Concepts of technologies and AI/Middle_East_dataset.csv', index = False)

# displaying the filtered middle east dataset
middle_east_dataset
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %% [markdown]
# Complete the following task:
# 1. Descriptive Statistics:
#
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
#
# • Which region has higher happiness Scores on average?

# %%
# 1.
# calciulating mean, standard deviation of score for south asia dataset
south_asia_mean = south_asia_dataset['score'].mean()
south_asia_std = south_asia_dataset['score'].std()

# calciulating mean, standard deviation of score for middle east dataset
middle_east_mean = middle_east_dataset['score'].mean()
middle_east_std = middle_east_dataset['score'].std()

# printing their outputs
print(f"Mean of South Asia: {south_asia_mean} and Standard Deviation of South Asia: {south_asia_std}")
print(f"Mean of Middle East: {middle_east_mean} and Standard Deviation of Middle East: {middle_east_std}")

# Using If statement for determining which region has higher happiness Scores on average
if(south_asia_mean > middle_east_mean):
  print("South Asia has higher happiness Scores on average.")
else:
  print("Middle East has higher happiness Scores on average.")
# Out:
# Mean of South Asia: 3.895666666666667 and Standard Deviation of South Asia: 1.1770690152521504
# Mean of Middle East: 5.412100000000001 and Standard Deviation of Middle East: 1.5662011684327144
# Middle East has higher happiness Scores on average.

# %% [markdown]
# 2. Top and Bottom Performers:
#
# • Identify the top 3 and bottom 3 countries in each region based on the score.
#
# • Plot bar charts comparing these charts.

# %%
# 2.
# identifying top 3 and bottom 3 countries in South Asia based on the score
top_3_south_asia = south_asia_dataset.nlargest(3, 'score')
bottom_3_south_asia = south_asia_dataset.nsmallest(3, 'score')

# identifying top 3 and bottom 3 countries in Middle East based on the score
top_3_middle_east = middle_east_dataset.nlargest(3, 'score')
bottom_3_middle_east = middle_east_dataset.nsmallest(3, 'score')

# printing output for Top 3 South Asia Countries
print("Top 3 South Asia Countries:")
top_3_south_asia
# Out:
# Top 3 South Asia Countries:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
#
#      Perceptions of corruption  Dystopia + residual Happiness Category  \
# 92                       0.115                1.783             Medium
# 107                      0.074                1.907             Medium
# 125                      0.122                0.756             Medium
#
#      Composite Score  GDP Score Gap
# 92            0.8159         -4.193
# 107           0.7039         -3.588
# ...

# %%
# printing output for Bottom 3 South Asia Countries
print("Bottom 3 South Asia Countries:")
bottom_3_south_asia
# Out:
# Bottom 3 South Asia Countries:
#     Country name  score  Log GDP per capita  Social support  \
# 142  Afghanistan  1.721               0.628           0.000
# 128   Bangladesh  3.886               1.122           0.249
# 127    Sri Lanka  3.898               1.361           1.179
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 142                    0.242                         0.000       0.091
# 128                    0.513                         0.775       0.140
# 127                    0.586                         0.583       0.144
#
#      Perceptions of corruption  Dystopia + residual Happiness Category  \
# 142                      0.088                0.672                Low
# 128                      0.167                0.919                Low
# 127                      0.031                0.014                Low
#
#      Composite Score  GDP Score Gap
# 142           0.3238         -1.093
# 128           0.6774         -2.764
# ...

# %%
# printing output for Top 3 Middle East Countries
print("Top 3 Middle East Countries:")
top_3_middle_east
# Out:
# Top 3 Middle East Countries:
#             Country name  score  Log GDP per capita  Social support  \
# 4                 Israel  7.341               1.803           1.513
# 12                Kuwait  6.951               1.845           1.364
# 21  United Arab Emirates  6.733               1.983           1.164
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                     0.740                         0.641       0.153
# 12                    0.661                         0.827       0.200
# 21                    0.563                         0.815       0.209
#
#     Perceptions of corruption  Dystopia + residual Happiness Category
# 4                       0.193                2.298               High
# 12                      0.172                1.884               High
# 21                      0.258                1.741               High

# %%
# printing output for Bottom 3 Middle East Countries
print("Bottom 3 Middle East Countries:")
bottom_3_middle_east
# Out:
# Bottom 3 Middle East Countries:
#     Country name  score  Log GDP per capita  Social support  \
# 141      Lebanon  2.707               1.377           0.577
# 132        Yemen  3.561               0.671           1.281
# 124       Jordan  4.186               1.262           0.983
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 141                    0.556                         0.173       0.068
# 132                    0.293                         0.362       0.080
# 124                    0.594                         0.593       0.059
#
#      Perceptions of corruption  Dystopia + residual Happiness Category
# 141                      0.029               -0.073                Low
# 132                      0.113                0.760                Low
# 124                      0.189                0.504             Medium

# %%
# bar plot for Top 3 South Asia Countries
plt.figure(figsize=(10, 6))
plt.bar(top_3_south_asia['Country name'], top_3_south_asia['score'], color='green')
plt.xlabel('Country name')
plt.ylabel('score')
plt.title('Top 3 South Asia Countries by Score')
plt.show()

# bar plot for Bottom 3 South Asia Countries
plt.figure(figsize=(10, 6))
plt.bar(bottom_3_south_asia['Country name'], bottom_3_south_asia['score'], color='orange')
plt.xlabel('Country name')
plt.ylabel('score')
plt.title('Bottom 3 South Asia Countries by Score')
plt.show()

# bar plot for Top 3 Middle East Countries
plt.figure(figsize=(10, 6))
plt.bar(top_3_middle_east['Country name'], top_3_middle_east['score'], color='blue')
plt.xlabel('Country name')
plt.ylabel('score')
plt.title('Top 3 Middle East Countries by Score')
plt.show()

# bar plot for Bottom 3 Middle East Countries
plt.figure(figsize=(10, 6))
plt.bar(bottom_3_middle_east['Country name'], bottom_3_middle_east['score'], color='yellow')
plt.xlabel('Country name')
plt.ylabel('score')
plt.title('Bottom 3 Middle East Countries by Score')
plt.show()

# %% [markdown]
# 3. Metric Comparisons:
#
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy between the regions using grouped bar charts.
#
# • Which metrics show the largest disparity between the two regions?

# %%
# 3.
# Comparing key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy between the regions
metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']

# Calculate the mean for metric in South Asia Countries
south_asia_mean = south_asia_dataset[metrics].mean()

# Calculate the mean for metric in Middle East Countries
middle_east_mean = middle_east_dataset[metrics].mean()

#Creating dataset for storing mean of both South Asia and Middle East
relation_dataset=pd.DataFrame({'South Asia':south_asia_mean,'Middle East':middle_east_mean})

# Creating group bar chart for comparing mean values of metrices between the regions
relation_dataset.plot(kind='bar',figsize=(10,6),color=['green','purple'])
plt.title('Comparison of Key Metrics between South Asia and Middle East')
plt.xlabel('Metrics')
plt.ylabel('Mean Values')
plt.xticks(rotation=0)
plt.legend(title='Region')
# displaying bar chart
plt.show()

# %%
# Determining which metrics show the largest disparity between two regions
disparities = abs(south_asia_mean - middle_east_mean)
largest_disparity_metric = disparities.idxmax()
print(f"The metrics which shows the largest disparity between two regions is: {largest_disparity_metric}")
# Out:
# The metrics which shows the largest disparity between two regions is: Social support

# %% [markdown]
# 4. Happiness Disparity:
#
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
#
# • Which region has greater variability in happiness?

# %%
# Compute the range (max - min) and coefficient of variation (CV) for Score in both regions
south_asia_range = south_asia_dataset['score'].max() - south_asia_dataset['score'].min()
south_asia_cv = south_asia_dataset['score'].std() / south_asia_dataset['score'].mean()

middle_east_range = middle_east_dataset['score'].max() - middle_east_dataset['score'].min()
middle_east_cv = middle_east_dataset['score'].std() / middle_east_dataset['score'].mean()

print(f"South Asia - Range: {south_asia_range}, Coefficient of Variation: {south_asia_cv}")
print(f"Middle East - Range: {middle_east_range}, Coefficient of Variation: {middle_east_cv}")

# Determine which region has greater variability in happiness
if south_asia_cv > middle_east_cv:
  print("South Asia has greater variability in happiness.")
else:
  print("Middle East has greater variability in happiness.")
# Out:
# South Asia - Range: 3.4370000000000003, Coefficient of Variation: 0.3021482883337427
# Middle East - Range: 4.634, Coefficient of Variation: 0.28938880812119405
# South Asia has greater variability in happiness.

# %% [markdown]
# 5. Correlation Analysis:
#
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and Generosity within each region.
#
# • Create scatter plots to visualize and interpret the relationships.

# %%
# Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and Generosity within each region
metrics_to_correlate = ['Freedom to make life choices', 'Generosity']

# Calculating correlation for South Asia
south_asia_correlation = south_asia_dataset[metrics_to_correlate + ['score']].corr()['score'].drop('score')

# Calculating correlation for Middle East
middle_east_correlation = middle_east_dataset[metrics_to_correlate + ['score']].corr()['score'].drop('score')

# printing their outputs
print("South Asia Correlation:")
print(south_asia_correlation)
print("\nMiddle East Correlation:")
print(middle_east_correlation)

# Create scatter plots to visualize and interpret the relationship
# South Asia - Freedom to Make Life Choices against Score
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Freedom to make life choices', y='score', data = south_asia_dataset, color='green')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')
plt.title('South Asia: Freedom to Make Life Choices against Score')
plt.show()

# South Asia - Generosity against Score
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Generosity', y='score', data=south_asia_dataset, color='blue')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.title('South Asia: Generosity against Score')
plt.show()

# Middle East - Freedom to Make Life Choices against Score
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Freedom to make life choices', y='score', data = middle_east_dataset, color='orange')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')
plt.title('Middle East: Freedom to Make Life Choices against Score')
plt.show()

# Middle East - Generosity against Score
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Generosity', y='score', data=middle_east_dataset, color='purple')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.title('Middle East: Generosity against Score')
plt.show()
# Out:
# South Asia Correlation:
# Freedom to make life choices    0.800519
# Generosity                      0.874512
# Name: score, dtype: float64
#
# Middle East Correlation:
# Freedom to make life choices    0.863220
# Generosity                      0.627524
# Name: score, dtype: float64

# %% [markdown]
# 6. Outlier Detection:
#
# • Identify outlier countries in both regions based on Score and GDP per Capita.
#
# • Plot these outliers and discuss their implications.

# %%
# 6.
# Calculating IQR for score in South asia
Q1_score_south_asia = south_asia_dataset['score'].quantile(0.25)
Q3_score_south_asia = south_asia_dataset['score'].quantile(0.75)
IQR_score_south_asia = Q3_score_south_asia - Q1_score_south_asia

# Calculating IQR for Log GDP per capita in South asia
Q1_gdp_south_asia = south_asia_dataset['Log GDP per capita'].quantile(0.25)
Q3_gdp_south_asia = south_asia_dataset['Log GDP per capita'].quantile(0.75)
IQR_gdp_south_asia = Q3_gdp_south_asia - Q1_gdp_south_asia

# calculating lower and upper bounds for score in South asia
lower_bound_score_south_asia = Q1_score_south_asia - 1.5 * IQR_score_south_asia
upper_bound_score_south_asia = Q3_score_south_asia + 1.5 * IQR_score_south_asia

# calculating lower and upper bounds for Log GDP per capita in South asia
lower_bound_gdp_south_asia = Q1_gdp_south_asia - 1.5 * IQR_gdp_south_asia
upper_bound_gdp_south_asia = Q3_gdp_south_asia + 1.5 * IQR_gdp_south_asia

# Identifying outliers in South asia
south_asia_outliers = south_asia_dataset[(south_asia_dataset['score'] < lower_bound_score_south_asia) | (south_asia_dataset['score'] > upper_bound_score_south_asia) | (south_asia_dataset['Log GDP per capita'] < lower_bound_gdp_south_asia) | (south_asia_dataset['Log GDP per capita'] > upper_bound_gdp_south_asia)]

# Calculating IQR for score in Middle east
Q1_score_middle_east = middle_east_dataset['score'].quantile(0.25)
Q3_score_middle_east = middle_east_dataset['score'].quantile(0.75)
IQR_score_middle_east = Q3_score_middle_east - Q1_score_middle_east

# Calculating IQR for  in Middle east
Q1_gdp_middle_east = middle_east_dataset['Log GDP per capita'].quantile(0.25)
Q3_gdp_middle_east = middle_east_dataset['Log GDP per capita'].quantile(0.75)
IQR_gdp_middle_east = Q3_gdp_middle_east - Q1_gdp_middle_east

# calculating lower and upper bounds for score in Middle east
lower_bound_score_middle_east = Q1_score_middle_east - 1.5 * IQR_score_middle_east
upper_bound_score_middle_east = Q3_score_middle_east + 1.5 * IQR_score_middle_east

# calculating lower and upper bounds for Log GDP per capita in Middle east
lower_bound_gdp_middle_east = Q1_gdp_middle_east - 1.5 * IQR_gdp_middle_east
upper_bound_gdp_middle_east = Q3_gdp_middle_east + 1.5 * IQR_gdp_middle_east

# Identifying outliers in Middle east
middle_east_outliers = middle_east_dataset[(middle_east_dataset['score'] < lower_bound_score_middle_east) | (middle_east_dataset['score'] > upper_bound_score_middle_east) | (middle_east_dataset['Log GDP per capita'] < lower_bound_gdp_middle_east) | (middle_east_dataset['Log GDP per capita'] > upper_bound_gdp_middle_east)]

# %%
#
# Creating scatter plot for South Asia outliers
plt.figure(figsize=(10, 6))
plt.scatter(south_asia_dataset['Log GDP per capita'], south_asia_dataset['score'], color='orange', label='Normal')
plt.scatter(south_asia_outliers['Log GDP per capita'], south_asia_outliers['score'], color='blue', label='Outliers')
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
plt.title('South Asia: GDP per Capita against Score')
plt.legend()
plt.show()

# Creating scatter plot for Middle East outliers
plt.figure(figsize=(10, 6))
plt.scatter(middle_east_dataset['Log GDP per capita'], middle_east_dataset['score'], color='green', label='Normal')
plt.scatter(middle_east_outliers['Log GDP per capita'], middle_east_outliers['score'], color='yellow', label='Outliers')
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
plt.title('Middle East: GDP per Capita against Score')
plt.legend()
plt.show()

# %% [markdown]
# 7. Visualization:
#
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
#
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
# 7.
# Creating boxplot for comparing distribution of Score between South Asia and Middle East
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='score', data=pd.concat([south_asia_dataset.assign(Region='South Asia'), middle_east_dataset.assign(Region='Middle East')]))
plt.title("Comparison of distribution of Score between South Asia and Middle East")
plt.show()

# %% [markdown]
# The key differences in distribution shapes, medians, and outliers:-
# 1. Distribution shapes:- The shape of boxplot indicates the spread skewness of data. Wider box more variability and narrower box indicates less variability.
# 2. Medians:- The line inside the box represents the median score.
# 3. Outliers:- The data point which goes outside the average values are outliers. The countries with outliers have the score significantly different from others.
